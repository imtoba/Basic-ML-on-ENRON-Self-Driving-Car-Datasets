# %%
import matplotlib.pyplot as plt
from prep_terrain_data import makeTerrainData
from class_vis import prettyPicture

features_train, labels_train, features_test, labels_test = makeTerrainData()

# %% [markdown]
# ### the training data (features_train, labels_train) have both "fast" and "slow"
# ### points mixed together--separate them so we can give them different colors
# ### in the scatterplot and identify them visually

# %%
grade_fast = [features_train[ii][0] for ii in range(0, len(features_train)) if labels_train[ii]==0]
bumpy_fast = [features_train[ii][1] for ii in range(0, len(features_train)) if labels_train[ii]==0]
grade_slow = [features_train[ii][0] for ii in range(0, len(features_train)) if labels_train[ii]==1]
bumpy_slow = [features_train[ii][1] for ii in range(0, len(features_train)) if labels_train[ii]==1]

# %% [markdown]
# #### initial visualization

# %%
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.scatter(bumpy_fast, grade_fast, color = "b", label="fast")
plt.scatter(grade_slow, bumpy_slow, color = "r", label="slow")
plt.legend()
plt.xlabel("bumpiness")
plt.ylabel("grade")
plt.show()

# %% [markdown]
# ### your code here!  name your classifier object clf if you want the
# ### visualization code (prettyPicture) to show you the decision boundary

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
clf=RandomForestClassifier()

# %%
clf=clf.fit(features_train,labels_train)

# %%
pred=clf.predict(features_test)

# %%
acc=accuracy_score(pred,labels_test)

# %% [markdown]
# #### mind here we found that the ORDER of  parameters of accuracy_score() doesnt matter
# ###### *STILL WE'LL CROSS CHECK ON TERMINAL**

# %%
print acc
# Out:
# 0.92

# %% [markdown]
# ## Lets Play with Some Parameters of this Classifier
# 1> n_estimators {=10 by default}

# %%
clf=RandomForestClassifier(n_estimators=10000)

# %%
clf=clf.fit(features_train,labels_train)

# %%
print acc
# Out:
# 0.92

# %%
print acc
#val=100
# Out:
# 0.92

# %%
print acc
#val=1000
# Out:
# 0.916

# %% [markdown]
# ### on decreasing n_estimator val considerably(order of 10) the accuracy decreases
# ***hmmmm or does the accuracy differs with different dataset??***

# %%
print acc
#val=5
# Out:
# 0.916

# %%
print acc
#val=8
# Out:
# 0.92

# %%
print acc
#val=7
# Out:
# 0.92

# %% [markdown]
# ## *No meaning to tweak it! BUT we can say accuracy decreases faster on decreasing than on incresaing the n_estimator val as is clear from results*

# %%
try:
    prettyPicture(clf, features_test, labels_test)
except NameError:
    pass

# %%
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.scatter(bumpy_fast, grade_fast, color = "b", label="fast")
plt.scatter(grade_slow, bumpy_slow, color = "r", label="slow")
plt.legend()
plt.xlabel("bumpiness")
plt.ylabel("grade")
plt.show()

# %% [markdown]
# # *mind the particular order as above(First the algo---> try-except--> plot code) for visual representation*

# %% [markdown]
# # _*ON A DETAILED ANALYSIS OF ACC SCORES IT TURnED OUT THAT ITS INDEPENDENT FOR THE SAME n_estimator value THE OUTPUT RANDOMLY CAME OUT TO B 92 AND 91.6*
